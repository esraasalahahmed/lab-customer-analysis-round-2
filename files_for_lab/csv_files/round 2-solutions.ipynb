# %%
import pandas as pd  
import numpy as np


marketing_analysis = pd.read_csv('marketing_customer_analysis.csv')

#Show dataframe shape
marketing_analysis.shape
# Out:
# (10910, 26)

# %%
marketing_analysis.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
#standardize header names 

#headers to be lower case 
marketing_analysis.columns

cols = []
for column in marketing_analysis.columns:
    cols.append(column.lower())
cols
marketing_analysis.columns = cols

marketing_analysis.columns
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size',
#        'vehicle type'],
#       dtype='object')

# %%
#remane headers 

marketing_analysis = marketing_analysis.rename(columns={'employmentstatus':'employment status'})
marketing_analysis.head()
# Out:
#    unnamed: 0 customer       state  customer lifetime value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective to date employment status gender  ...  \
# 0     Basic   College           2/18/11          Employed      M  ...
# 1     Basic   College           1/18/11        Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11          Employed      M  ...
# 3  Extended   College           1/11/11          Employed      M  ...
# 4   Premium  Bachelor           1/17/11     Medical Leave      F  ...
#
#    number of open complaints number of policies     policy type        policy  \
# ...

# %%
# replace space with '_'

marketing_analysis.columns = marketing_analysis.columns.str.replace(' ', '_')
marketing_analysis.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employment_status', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %%
# types of columns 'numerical or categorical'

marketing_analysis.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employment_status                 object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
marketing_analysis = marketing_analysis.drop(['unnamed:_0'], axis=1)

marketing_analysis.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employment_status', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type'],
#       dtype='object')

# %%
#show columns which are numerical
marketing_analysis.select_dtypes(np.number)
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
#show columns which are categorical 
marketing_analysis.select_dtypes(object)
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employment_status gender location_code marital_status     policy_type  \
# ...

# %%
#check NaN values
#first check for duplicate and get rid of duplicate data if any

sum(marketing_analysis.duplicated())
marketing_analysis= marketing_analysis.drop_duplicates()
marketing_analysis.isna().sum()
# Out:
# customer                            0
# state                             614
# customer_lifetime_value             0
# response                          614
# coverage                            0
# education                           0
# effective_to_date                   0
# employment_status                   0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           623
# months_since_policy_inception       0
# number_of_open_complaints         623
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     608
# vehicle_size                      608
# vehicle_type                     5465
# ...

# %%
round(marketing_analysis.isna().sum()/len(marketing_analysis),4)*100  # shows the percentage of null values in a column

nulls_df = pd.DataFrame(round(marketing_analysis.isna().sum()/len(marketing_analysis),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                       header_name  percent_nulls
# 0                        customer           0.00
# 1                           state           5.65
# 2         customer_lifetime_value           0.00
# 3                        response           5.65
# 4                        coverage           0.00
# 5                       education           0.00
# 6               effective_to_date           0.00
# 7               employment_status           0.00
# 8                          gender           0.00
# 9                          income           0.00
# 10                  location_code           0.00
# 11                 marital_status           0.00
# 12           monthly_premium_auto           0.00
# 13        months_since_last_claim           5.73
# 14  months_since_policy_inception           0.00
# 15      number_of_open_complaints           5.73
# 16             number_of_policies           0.00
# 17                    policy_type           0.00
# ...

# %%
#drop rows that have null values (only if there are very few)

# first checking rows that are null based on a specific column
marketing_analysis[marketing_analysis['state'].isna()==True].head(10) 

# Replacing null values for categorical variables
#marketing_analysis['state'].unique()
#marketing_analysis['state'].value_counts()

#marketing_analysis['state'].value_counts(dropna=False)
#marketing_analysis = marketing_analysis[marketing_analysis['state'].isna()==False] 
#marketing_analysis
# Out:
#     customer state  customer_lifetime_value response  coverage  \
# 5    HO81102   NaN              4745.181764      NaN     Basic
# 11   GE63585   NaN              2420.711888      NaN     Basic
# 58   BR69566   NaN             14019.833140      NaN     Basic
# 62   UF44021   NaN              2108.493744      NaN     Basic
# 126  TE60343   NaN              4716.264294      NaN     Basic
# 131  QK24293   NaN              6265.343299      NaN  Extended
# 155  JG35886   NaN              4111.888285      NaN   Premium
# 168  FV22585   NaN              6960.920371      NaN  Extended
# 169  AU23837   NaN              5010.379310      NaN     Basic
# 190  VZ18907   NaN             21991.615980      NaN     Basic
#
#                 education effective_to_date employment_status gender  income  \
# 5    High School or Below        2011-02-14          Employed      M   50549
# 11               Bachelor        2011-02-07          Employed      M   31710
# ...

# %%
#marketing_analysis.isna().sum() #change ocurre for state and response columns
marketing_analysis.shape

# %%
#Dtaetime format

marketing_analysis.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employment_status gender  income  ...  \
# 0           2/18/11          Employed      M   48029  ...
# 1           1/18/11        Unemployed      F       0  ...
# 2           2/10/11          Employed      M   22139  ...
# 3           1/11/11          Employed      M   49078  ...
# 4           1/17/11     Medical Leave      F   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# ...

# %%
marketing_analysis['effective_to_date'] = pd.to_datetime(marketing_analysis['effective_to_date'], errors='coerce')
marketing_analysis.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employment_status gender  income  ...  \
# 0        2011-02-18          Employed      M   48029  ...
# 1        2011-01-18        Unemployed      F       0  ...
# 2        2011-02-10          Employed      M   22139  ...
# 3        2011-01-11          Employed      M   49078  ...
# 4        2011-01-17     Medical Leave      F   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# ...

# %%
#Extract the months from the dataset

marketing_analysis['month'] = pd.DatetimeIndex(marketing_analysis['effective_to_date']).month
marketing_analysis
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employment_status gender  income  ...  \
# ...

# %%
#Filter the data

marketing_analysis[(marketing_analysis['month']==1) | (marketing_analysis['month']==2) | (marketing_analysis['month']==3)]
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employment_status gender  income  ...  \
# ...

# %% [markdown]
# # lab_Round 3

# %%
#Show dataframe info

marketing_analysis.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employment_status                        object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
#Describe dataframe

marketing_analysis.describe().T
# Out:
#                                  count          mean           std  \
# customer_lifetime_value        10873.0   8016.881720   6884.829202
# income                         10873.0  37537.101444  30362.078350
# monthly_premium_auto           10873.0     93.216684     34.454801
# months_since_last_claim        10250.0     15.145073     10.078893
# months_since_policy_inception  10873.0     48.098777     27.929932
# number_of_open_complaints      10250.0      0.383512      0.911190
# number_of_policies             10873.0      2.977467      2.397752
# total_claim_amount             10873.0    434.902879    292.233402
# month                          10873.0      1.466661      0.498910
#
#                                        min          25%           50%  \
# customer_lifetime_value        1898.007675  4014.453113   5768.830622
# income                            0.000000     0.000000  33811.000000
# monthly_premium_auto             61.000000    68.000000     83.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
#A plot of total number of responses

sns.displot(marketing_analysis['response'], bins=100) 
plt.show()

# %%
#Create response rate column
marketing_analysis['response rate']= marketing_analysis['response'].map({'Yes': 1, 'No': 0})
marketing_analysis
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employment_status gender  income  ...  \
# ...

# %%
#A plot of the response rate by the sales channel

sns.barplot(x="response rate", y="sales_channel", data=marketing_analysis) 
plt.show()

# %%
#A plot of the response rate by the total claim amount

sns.barplot(x="response rate", y="total_claim_amount", data=marketing_analysis) 
plt.show()

# %%
#A plot of the response rate by income

sns.barplot(x="response rate", y="income", data=marketing_analysis) 
plt.show()
